# %% [markdown]
# This notebook aims at exploring all the possibilities for parsing CPC titles into title-hyponyms structure.

# %% [markdown]
# # Data preprocessing

# %%
from anytree import Node, RenderTree
import re 
import pandas as pd

# %%
TARGET_LEVEL = 6

global dict_lvl
dict_lvl = {1: -3, 3: -2, 4: -1, 6: 0}

def convert_to_int(x):
    lvl = x['lvl']
    try:
        return int(lvl)
    except ValueError:
        title = x['title']
        if len(title) == 1:
            return -3
        elif len(title) == 3:
            return -2
        elif len(title) == 4:
            return -1

def clean_descr(description):
    """
    1. remove references from the description, such as *** (preserving A23B; obtaining protein compositions for foodstuffs A23J1/00;)
    2. remove '{' and '}'
    3. remove i.e. ***
    """
    description = description.replace('{', '').replace('}','')
    description = re.sub(r'\ ?\([\w\W]*([A-Z]{1}[0-9]{2}[A-Z]{1}[0-9]*[\/]*[0-9]*)*[\w\W]*\)', '', description)
    description = re.sub(r'[ ,]*i\.e\..*', '', description)
    return description.lower()

def has_cpc(description):
    """
    4. check whether a title desciption has CPC code inside
    e.g. having alternatively specified atoms bound to the phosphorus atom and not covered by a single one of groups A01N57/10, A01N57/18, A01N57/26, A01N57/34
    """
    cpc_pattern = r'[A-Za-z]{1}[0-9]{2}[A-Za-z]{0,1}[0-9]*[\/]*[0-9]*'
    match = re.search(cpc_pattern, description)
    if match:
        return True
    else:
        return False

def is_trash_title(description):
    """
    5. check whether a title description is a trash title
    """
    description = description.lower()
    if ("subject matter not" in description and "provided for in" in description) or ("covered by" in description and (" subclass " in description or " groups " in description) and " other " in description) or ("dummy group" in description):
        return True
    else:
        return False

def next_same_lvl_index(subdf,lvl):
    lvl_df = subdf[subdf['lvl'] == lvl]
    idx_df = lvl_df.index
    if len(idx_df) == 1:
        return idx_df[0]

    res_index = idx_df[1] - 1
    return res_index

def rm_title_with_subtree(dataframe):
    """
    6. remove those titles with codes in their description and its subtree titles
    """
    # get indices of description 
    dataframe = dataframe.reset_index(drop=True)
    id_hascpc = dataframe[dataframe['description'].apply(has_cpc) | dataframe['description'].apply(is_trash_title)].index
    
    idx_to_drop = []
    for i in id_hascpc:
        l = dataframe.iloc[i]
        if i == (dataframe.shape[0]-1) or l['lvl'] >= dataframe.iloc[i+1]['lvl']: 
            idx_to_drop.append(i)
        else:
            j = next_same_lvl_index(dataframe[i:], l['lvl'])
            if i == j:
                idx_to_drop.append(i)
            elif j>i:
                idx_to_drop.extend(range(i,j+1))
            else:
                raise ValueError("Problem with subtree index!")

    dataframe = dataframe.drop(idx_to_drop)
    return dataframe.reset_index(drop=True)

def read_label_file(file_name, max_level=TARGET_LEVEL):
    df = pd.read_csv(file_name, header=None, sep='\t', dtype=object, names=['title', 'lvl', 'description'])
    df['lvl'] = df.apply(convert_to_int, axis=1)

    if max_level in [1,3,4,6]:
        df = df[df['lvl']<=dict_lvl[max_level]]

    df['description'] = df['description'].apply(clean_descr)
    df = rm_title_with_subtree(df)
    return df.dropna().reset_index(drop=True)

def find_father(df, child_lvl):
    for i, row in df[::-1].iterrows():
        if row.lvl + 1 == child_lvl:
            return row.title

def build_tree(df):
    node_dict = {}
    root_title = df.loc[0, 'title']
    root_desc = df.loc[0, 'description']
    node_dict[root_title] = Node(root_desc)

    for i, row in df[1:].iterrows():
        child_lvl = row.lvl
        child_title = row.title
        child_desc = row.description

        father_title = find_father(df[:i], child_lvl)
        node_dict[child_title] = Node(child_desc, parent = node_dict[father_title])
    return node_dict[root_title]

# %%
A_df = read_label_file('cpc-titles/cpc-section-A_20220201.txt')
B_df = read_label_file('cpc-titles/cpc-section-B_20220201.txt')
C_df = read_label_file('cpc-titles/cpc-section-C_20220201.txt')
D_df = read_label_file('cpc-titles/cpc-section-D_20220201.txt')
E_df = read_label_file('cpc-titles/cpc-section-E_20220201.txt')
F_df = read_label_file('cpc-titles/cpc-section-F_20220201.txt')
G_df = read_label_file('cpc-titles/cpc-section-G_20220201.txt')
H_df = read_label_file('cpc-titles/cpc-section-H_20220201.txt')

# %%
A_df
# Out:
#           title  lvl                                        description
# 0             A   -3                                  human necessities
# 1           A01   -2  agriculture; forestry; animal husbandry; hunti...
# 2          A01B   -1  soil working in agriculture or forestry; parts...
# 3      A01B1/00    0                                         hand tools
# 4      A01B3/00    0                   ploughs with fixed plough-shares
# ...         ...  ...                                                ...
# 1274  A63J21/00    0  conjuring appliances; auxiliary apparatus for ...
# 1275  A63J25/00    0            equipment specially adapted for cinemas
# 1276       A63K   -1  racing; riding sports; equipment or accessorie...
# 1277   A63K1/00    0                          race-courses; race-tracks
# 1278   A63K3/00    0  equipment or accessories for racing or riding ...
#
# [1279 rows x 3 columns]

# %%
for pre, fill, node in RenderTree(build_tree(A_df)):
    print("%s%s" % (pre, node.name))
# Out:
# human necessities
# ├── agriculture; forestry; animal husbandry; hunting; trapping; fishing
# │   ├── soil working in agriculture or forestry; parts, details, or accessories of agricultural machines or implements, in general
# │   │   ├── hand tools
# │   │   ├── ploughs with fixed plough-shares
# │   │   ├── ploughs with rolling non-driven tools, e.g. discs
# │   │   ├── disc-like soil-working implements usable either as ploughs or as harrows, or the like
# │   │   ├── ploughs with rotary driven tools
# │   │   ├── ploughs with oscillating, digging or piercing tools driven or not
# │   │   ├── ploughs or like machines for special purposes
# │   │   ├── elements, tools, or details of ploughs
# │   │   ├── ploughs with special additional arrangements, e.g. means for putting manure under the soil, clod-crushers; means for breaking the subsoil
# │   │   ├── harrows with non-rotating tools
# │   │   ├── harrows with rotary non-driven tools
# │   │   ├── elements, tools, or details of harrows
# │   │   ├── harrows with special additional arrangements, e.g. means for distributing fertilisers; harrows for special purposes
# │   │   ├── clod-crushers
# │   │   ├── rollers
# │   │   ├── drags graders for field cultivators
# │   │   ├── tilling implements with rotary driven tools , e.g. in combination with fertiliser distributors or seeders, with grubbing chains, with sloping axles, with driven discs
# │   │   ├── other machines for working soil not specially adapted for working soil on which crops are growing
# │   │   ├── devices for loosening soil compacted by wheels or the like
# │   │   ├── other machines specially adapted for working soil on which crops are growing
# │   │   ├── thinning machines
# │   │   ├── gatherers for removing stones, undesirable roots or the like from the soil, e.g. tractor-drawn rakes
# │   │   ├── machines for treating meadows or lawns , e.g. for sports grounds
# │   │   ├── soil-working with electric potential applied between tools and soil
# │   │   ├── combined machines
# │   │   ├── undercarriages specially adapted for mounting-on various kinds of agricultural tools or apparatus
# │   │   ├── devices specially adapted for connection between animals or tractors and agricultural machines or implements
# │   │   ├── devices for, or parts of, agricultural machines or implements for preventing overstrain
# │   │   ├── lifting or adjusting devices or arrangements for agricultural machines or implements
# │   │   ├── devices for controlling the tractor motor by resistance of tools
# │   │   ├── steering of agricultural machines or implements; guiding agricultural machines or implements on a desired track
# │   │   ├── construction or arrangement of setting or adjusting mechanisms, of implement or tool drive or of power take-off; means for protecting parts against dust, or the like; adapting machine elements to or for agricultural purposes
# │   │   ├── means or arrangements to facilitate transportation of agricultural machines or implements, e.g. folding frames to reduce overall width
# │   │   ├── carriers for supporting persons when working in the field, e.g. while thinning beet
# │   │   ├── machines for lifting and treating soil
# │   │   └── methods for working soil
# │   ├── planting; sowing; fertilising
# │   │   ├── apparatus, or methods of use thereof, for testing or treating seed, roots, or the like, prior to sowing or planting
# │   │   ├── treating manure; manuring
# │   │   ├── making or covering furrows or holes for sowing, planting or manuring
# │   │   ├── sowing
# │   │   ├── potato planters
# │   │   ├── transplanting machines
# │   │   ├── machines or apparatus for consolidating soil around plants
# │   │   ├── fertiliser distributors
# │   │   ├── fertilisers or seeders with centrifugal wheels
# │   │   ├── arrangements for driving working parts of fertilisers or seeders
# │   │   ├── methods of fertilising , sowing or planting
# │   │   └── distributing devices specially adapted for liquid manure or other fertilising liquid, including ammonia, e.g. transport tanks or sprinkling wagons
# │   ├── harvesting; mowing
# │   │   ├── hand-cutting implements for harvesting
# │   │   ├── non-abrasive sharpening devices for scythes, sickles or the like
# │   │   ├── containers for whetstones for use during harvesting
# │   │   ├── rakes
# │   │   ├── forks
# │   │   ├── other hand implements
# │   │   ├── diggers, e.g. potato ploughs
# │   │   ├── digging machines with sieve graters but without conveying mechanisms
# │   │   ├── digging machines with sieving and conveying mechanisms
# │   │   ├── digging machines with centrifugal wheels, drums or spinners
# │   │   ├── digging machines with potato-picking implements
# │   │   ├── topping machines
# │   │   ├── lifters for beet or like crops
# │   │   ├── machines with both topping and lifting mechanisms
# │   │   ├── harvesters for peanuts
# │   │   ├── other digging harvesters
# │   │   ├── accessories for digging harvesters
# │   │   ├── mowers; mowing apparatus of harvesters
# │   │   ├── reaper-binders
# │   │   ├── independent binders, e.g. for hay; binders attachable to mowers
# │   │   ├── combines
# │   │   ├── mowers convertible to apparatus for purposes other than mowing; mowers capable of performing operations other than mowing
# │   │   ├── mowers combined with apparatus performing additional operations while mowing
# │   │   ├── harvesting of underwater plants, e.g. harvesting of seaweed
# │   │   ├── harvesting of standing crops
# │   │   ├── picking of fruits, vegetables, hops, or the like; devices for shaking trees or shrubs
# │   │   ├── headers for topping of plants, e.g. stalks with ears
# │   │   ├── apparatus for gathering together crops spread on the soil, e.g. apples, beets, nuts, potatoes , cotton, cane sugar
# │   │   ├── delivering mechanisms for harvesters or mowers
# │   │   ├── equipment for binding harvested produce
# │   │   ├── elevators or conveyors for binders or combines
# │   │   ├── outside dividers
# │   │   ├── grain-crop lifters
# │   │   ├── undercarriages or frames specially adapted for harvesters or mowers; platforms
# │   │   ├── driving mechanisms or parts thereof for harvesters or mowers
# │   │   ├── accessories for harvesters or mowers
# │   │   ├── haymakers with tines that are stationary with respect to the machine during operation but that may be liftable for dumping
# │   │   ├── haymakers with tines moving with respect to the machine
# │   │   ├── parts or details of , or accessories for, haymakers
# │   │   ├── crop conditioners
# │   │   ├── arrangements for making or setting stacks
# │   │   ├── loaders for hay or like field crops
# │   │   ├── pick-ups for loaders, chaff-cutters, balers, field-threshers, or the like
# │   │   ├── vehicles for carrying harvested crops with means for selfloading or unloading
# │   │   ├── methods for harvesting agricultural products
# │   │   └── lawn-mowers
# │   ├── processing of harvested produce; hay or straw presses; devices for storing agricultural or horticultural produce
# │   │   ├── stationary apparatus or hand tools for forming or binding straw, hay or the like into bundles
# │   │   ├── hand-operated implements for cutting-up straw, hay or the like
# │   │   ├── hand-operated implements for threshing
# │   │   ├── threshing apparatus
# │   │   ├── threshing machines with flails; threshing devices with flails for combines
# │   │   ├── threshing apparatus specially adapted for maize; threshing apparatus specially adapted for particular crops other than cereals
# │   │   ├── parts or details of threshing apparatus
# │   │   ├── hand-operated baling apparatus
# │   │   ├── baling presses for straw, hay or the like
# │   │   ├── straw conveyors for threshing machines or baling presses
# │   │   ├── devices for securing threshing machines or baling presses to the ground, e.g. for compensating for unevenness of the ground
# │   │   ├── devices for protecting human beings for threshing machines or baling presses
# │   │   ├── storing agricultural or horticultural produce; hanging-up harvested fruit
# │   │   └── cutting apparatus specially adapted for cutting hay, straw or the like
# │   ├── horticulture; cultivation of vegetables, flowers, rice, fruit, vines, hops or seaweed; forestry; watering
# │   │   ├── vegetative propagation
# │   │   ├── cutting implements specially adapted for horticultural purposes; delimbing standing trees
# │   │   ├── floral handling
# │   │   ├── botany in general
# │   │   ├── cultivation in receptacles, forcing-frames or greenhouses; edging for beds, lawn or the like
# │   │   ├── sterilising soil by steam
# │   │   ├── protecting plants
# │   │   ├── devices or methods for influencing weather conditions
# │   │   ├── cultivation of hops, vines, fruit trees, or like trees
# │   │   ├── cultivation of mushrooms
# │   │   ├── cultivation of turf, lawn or the like; apparatus or methods therefor
# │   │   ├── devices for hanging-up harvested fruit
# │   │   ├── cultivation of specific crops or plants not otherwise provided for
# │   │   ├── forestry
# │   │   ├── growth substrates; culture media; apparatus or methods therefor
# │   │   ├── watering gardens, fields, sports grounds or the like
# │   │   ├── self-acting watering devices, e.g. for flower-pots
# │   │   ├── root feeders; injecting fertilisers into the roots
# │   │   ├── soilless cultivation, e.g. hydroponics
# │   │   └── cultivation of seaweed or algae
# │   ├── new plants or non-transgenic processes for obtaining them; plant reproduction by tissue culture techniques
# │   │   ├── processes for modifying genotypes ; plants characterised by associated natural traits
# │   │   ├── processes for modifying phenotypes , e.g. symbiosis with bacteria
# │   │   ├── plant reproduction by tissue culture techniques ; tissue culture techniques therefor
# │   │   ├── angiosperms
# │   │   ├── angiosperms
# │   │   ├── gymnosperms, e.g. conifers
# │   │   ├── pteridophytes, e.g. ferns, club-mosses, horse-tails
# │   │   ├── bryophytes, e.g. mosses, liverworts
# │   │   ├── algae
# │   │   ├── fungi; lichens
# │   │   └── symbiotic or parasitic combinations including one or more new plants, e.g. mycorrhiza
# │   ├── manufacture of dairy products
# │   │   ├── devices or accessories for milking by hand
# │   │   ├── milking with catheters
# │   │   ├── milking machines or devices
# │   │   ├── accessories for milking machines or devices
# │   │   ├── milk receptacles
# │   │   ├── apparatus for treating milk
# │   │   ├── tanks for treating cream
# │   │   ├── manufacturing butter
# │   │   ├── kneading machines for butter, or the like
# │   │   ├── hand devices for forming slabs of butter, or the like
# │   │   ├── machines for forming slabs of butter, or the like
# │   │   ├── devices for dividing bulk butter, or the like
# │   │   ├── cheese-making
# │   │   └── after-treatment of cheese; coating the cheese
# │   ├── animal husbandry; care of birds, fishes, insects; fishing; rearing or breeding animals, not otherwise provided for; new breeds of animals
# │   │   ├── housing animals; equipment therefor
# │   │   ├── pasturing equipment, e.g. tethering devices; grids for preventing cattle from straying; electrified wire fencing
# │   │   ├── feeding devices for stock or game; feeding wagons; feeding stacks
# │   │   ├── watering equipment for stock or game
# │   │   ├── sucking apparatus for young stock ; devices for mixing solid food with liquids
# │   │   ├── marking of animals
# │   │   ├── devices for grooming or caring of animals, e.g. curry-combs; fetlock rings; tail-holders; devices for preventing crib-biting; washing devices; protection against weather conditions or insects
# │   │   ├── removing the fleece from live sheep or similar animals
# │   │   ├── devices for taming animals, e.g. nose-rings or hobbles; devices for overturning animals in general; training or exercising equipment; covering boxes
# │   │   ├── dehorners; horn trainers
# │   │   ├── weaning apparatus
# │   │   ├── devices for assisting or preventing mating
# │   │   ├── manure or urine pouches
# │   │   ├── muzzles
# │   │   ├── leads or collars, e.g. for dogs
# │   │   ├── other apparatus for animal husbandry
# │   │   ├── housing birds
# │   │   ├── nest-eggs
# │   │   ├── marking poultry or other birds
# │   │   ├── constraining birds, e.g. wing clamps
# │   │   ├── feeding or drinking appliances for poultry or other birds
# │   │   ├── incubators for poultry
# │   │   ├── testing, sorting or cleaning eggs; pick-up devices
# │   │   ├── other aviculture appliances, e.g. devices for determining whether a bird is about to lay
# │   │   ├── beehives
# │   │   ├── rearing-boxes; queen transporting or introducing cages
# │   │   ├── appliances for treating beehives or parts thereof, e.g. for cleaning or disinfecting
# │   │   ├── feeding or drinking appliances for bees
# │   │   ├── bee-smokers; bee-keepers' accessories, e.g. veils
# │   │   ├── appliances for providing, preventing or catching swarms; drone-catching devices
# │   │   ├── honey collection
# │   │   ├── culture of aquatic animals
# │   │   ├── receptacles for live fish, e.g. aquaria; terraria
# │   │   ├── fish stringers
# │   │   ├── rearing or breeding animals, not otherwise provided for; new breeds of animals
# │   │   ├── stationary catching devices
# │   │   ├── floating nets
# │   │   ├── drawn nets
# │   │   ├── other catching nets or the like
# │   │   ├── accessories for fishing nets; details of fishing nets, e.g. structure
# │   │   ├── landing-nets for fishing; landing-spoons for fishing
# │   │   ├── harvesting oysters, mussels, sponges or the like
# │   │   ├── fishing with projectiles
# │   │   ├── fish-hooks
# │   │   ├── artificial bait for fishing
# │   │   ├── fishing rods
# │   │   ├── reels
# │   │   ├── lines
# │   │   ├── floats for angling, with or without signalling devices
# │   │   ├── sinkers for angling
# │   │   ├── accessories for angling
# │   │   ├── modified animals
# │   │   ├── genetically modified animals
# │   │   ├── animals characterised by species
# │   │   └── animals characterised by purpose
# │   ├── shoeing of animals
# │   │   ├── shoes for horses or other solipeds fastened with nails
# │   │   ├── horseshoes fastened by means other than nails, with or without additional fastening by nailing
# │   │   ├── horseshoes made of elastic materials
# │   │   ├── accessories for shoeing animals
# │   │   ├── shoes for other animals, e.g. oxen
# │   │   ├── farriers' tools and appliances
# │   │   ├── pens for animals while being shod
# │   │   └── apparatus or use of substances for the care of hoofs
# │   ├── catching, trapping or scaring of animals; apparatus for the destruction of noxious animals or noxious plants
# │   │   ├── stationary means for catching or killing insects
# │   │   ├── manual implements, other than sprayers or powder distributors, for catching or killing insects, e.g. butterfly nets
# │   │   ├── catching insects in fields, gardens, or forests by movable appliances
# │   │   ├── special adaptations or arrangements of liquid-spraying apparatus for purposes covered by this subclass
# │   │   ├── special adaptations or arrangements of powder-spraying apparatus for purposes covered by this subclass
# │   │   ├── special adaptations or arrangements of combined liquid- and powder-spraying apparatus for purposes covered by this subclass
# │   │   ├── fumigators; apparatus for distributing gases
# │   │   ├── flame-throwers specially adapted for purposes covered by this subclass
# │   │   ├── apparatus for the destruction of vermin in soil or in foodstuffs
# │   │   ├── apparatus for the destruction of noxious animals, other than insects, by hot water, steam, hot air, or electricity
# │   │   ├── apparatus for the destruction of unwanted vegetation, e.g. weeds
# │   │   ├── traps for animals
# │   │   ├── devices for dispensing poison for animals
# │   │   ├── apparatus having projectiles or killing implements projected to kill the animal, e.g. pierce or shoot, and triggered thereby
# │   │   ├── scaring or repelling devices, e.g. bird-scaring apparatus
# │   │   ├── hunting appliances
# │   │   └── kind of animal
# │   ├── preservation of bodies of humans or animals or plants or parts thereof; pest repellants or attractants; plant growth regulators
# │   │   ├── preservation of bodies of humans or animals, or parts thereof
# │   │   ├── preservation of plants or parts thereof, e.g. inhibiting evaporation, improvement of the appearance of leaves or protection against physical influences such as uv radiation using chemical compositions; grafting wax
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators, characterised by their forms, or by their non-active ingredients or by their methods of application , e.g. seed treatment or sequential application; substances for reducing the noxious effect of the active ingredients to organisms other than pests
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing hydrocarbons
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing halogenated hydrocarbons
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic oxygen or sulfur compounds
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic nitrogen compounds
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic compounds containing a carbon atom having two bonds to hetero atoms with at the most one bond to halogen, e.g. aldehyde radical
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic compounds containing a carbon atom having three bonds to hetero atoms with at the most two bonds to halogen, e.g. carboxylic acids
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic compounds containing a sulfur atom bound to a hetero atom
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing heterocyclic compounds
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators, containing compounds having three or more carbocyclic rings condensed among themselves, at least one ring not being a six-membered ring
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic compounds containing a carbon atom not being member of a ring and having no bond to a carbon or hydrogen atom, e.g. derivatives of carbonic acid
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic compounds having the sequences of atoms o—n—s, x—o—s, n—n—s, o—n—n or o-halogen, regardless of the number of bonds each atom has and with no atom of these sequences forming part of a heterocyclic ring
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing cyclopropane carboxylic acids or derivatives thereof
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators, containing organic compounds containing elements other than carbon, hydrogen, halogen, oxygen, nitrogen and sulfur
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing organic phosphorus compounds
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing elements or inorganic compounds
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing substances of unknown or undetermined composition, e.g. substances characterised only by the mode of action
# │   │   ├── biocides, pest repellants or attractants, or plant growth regulators containing microorganisms, viruses, microbial fungi, animals or substances produced by, or obtained from, microorganisms, viruses, microbial fungi or animals, e.g. enzymes or fermentates
# │   │   └── biocides, pest repellants or attractants, or plant growth regulators containing material from algae, lichens, bryophyta, multi-cellular fungi or plants, or extracts thereof
# │   └── biocidal, pest repellant, pest attractant or plant growth regulatory activity of chemical compounds or preparations
# │       ├── disinfectants; antimicrobial compounds or mixtures thereof
# │       ├── fungicides
# │       ├── nematocides
# │       ├── arthropodicides
# │       ├── molluscicides
# │       ├── rodenticides
# │       ├── herbicides; algicides
# │       ├── pest repellants
# │       ├── pest attractants
# │       ├── plant growth regulators
# │       └── chemosterilants
# ├── baking; edible doughs
# │   ├── bakers' ovens; machines or equipment for baking
# │   │   ├── bakers' ovens
# │   │   ├── baking apparatus employing high-frequency or infra-red heating
# │   │   ├── parts or accessories of ovens
# │   │   ├── baking apparatus for special goods; other baking apparatus
# │   │   └── baking plants
# │   ├── machines or equipment for making or processing doughs; handling baked articles made from dough
# │   │   ├── mixing or kneading machines for the preparation of dough
# │   │   ├── machines or apparatus for shaping batches of dough before subdivision
# │   │   ├── dough-dividing machines
# │   │   ├── machines which homogenise the subdivided dough by working other than by kneading
# │   │   ├── other apparatus for handling dough or dough pieces
# │   │   ├── other machines for forming the dough into its final shape before cooking or baking
# │   │   ├── provers
# │   │   └── apparatus for handling baked articles
# │   └── treatment, e.g. preservation, of flour or dough, e.g. by addition of materials; baking; bakery products; preservation thereof
# │       ├── treatment of flour or dough by adding materials thereto before or during baking
# │       ├── preserving flour or dough before baking by storage in an inert atmosphere
# │       ├── other treatment of flour or dough before baking, e.g. cooling, irradiating, heating
# │       ├── methods for preparing or baking dough
# │       ├── batters, dough or mixtures before baking
# │       ├── finished or partly finished bakery products
# │       ├── preserving finished , partly finished or par-baked bakery products; improving
# │       └── refreshing bakery products or recycling bakery products
# ├── butchering; meat treatment; processing poultry or fish
# │   ├── slaughtering
# │   │   ├── apparatus for fettering animals to be slaughtered
# │   │   ├── slaughtering or stunning
# │   │   ├── accessories for use during or after slaughtering
# │   │   └── slaughterhouse arrangements
# │   └── processing meat, poultry, or fish
# │       ├── apparatus for mixing meat, sausage-meat, or meat products
# │       ├── apparatus for pounding, forming, or pressing meat, sausage-meat, or meat products
# │       ├── apparatus for tenderising meat, e.g. ham
# │       ├── sausage making; apparatus for handling or conveying sausage products during manufacture
# │       ├── sausage casings
# │       ├── apparatus for hanging-up meat or sausages
# │       ├── other devices for processing meat or bones
# │       ├── plants, factories, or the like for processing meat
# │       ├── processing poultry
# │       ├── processing fish ; curing of fish; stunning of fish by electric current; investigating fish by optical means
# │       └── processing shellfish or bivalves, e.g. oysters, lobsters; devices therefor, e.g. claw locks, claw crushers, grading devices; processing lines
# ├── foods or foodstuffs; treatment thereof, not covered by other classes
# │   ├── preserving, e.g. by canning, meat, fish, eggs, fruit, vegetables, edible seeds; chemical ripening of fruit or vegetables; the preserved, ripened, or canned products
# │   │   ├── general methods for preserving meat, sausages, fish or fish products
# │   │   ├── preservation of eggs or egg products
# │   │   ├── preservation or chemical ripening of fruit or vegetables
# │   │   └── preservation of edible seeds, e.g. cereals
# │   ├── dairy products, e.g. milk, butter or cheese; milk or cheese substitutes; making thereof
# │   │   ├── concentration, evaporation or drying
# │   │   ├── preservation of milk or milk preparations
# │   │   ├── other dairy technology
# │   │   ├── milk preparations; milk powder or milk powder preparations
# │   │   ├── milk substitutes, e.g. coffee whitener compositions
# │   │   ├── cream; cream preparations; making thereof
# │   │   ├── butter; butter preparations; making thereof
# │   │   ├── buttermilk; buttermilk preparations
# │   │   ├── cheese; cheese preparations; making thereof
# │   │   ├── cheese substitutes
# │   │   ├── whey; whey preparations
# │   │   ├── other dairy products
# │   │   ├── special features
# │   │   ├── physical treatment of dairy products
# │   │   ├── biochemical treatment
# │   │   ├── aspects relating to animal feed or genotype
# │   │   ├── use or particular additives or ingredients
# │   │   ├── particular aspects related to cheese
# │   │   ├── particular aspects or types of dairy products
# │   │   └── aspects relating to packaging
# │   ├── edible oils or fats, e.g. margarines, shortenings, cooking oils
# │   │   ├── edible oil or fat compositions containing an aqueous phase, e.g. margarines
# │   │   └── other edible oils or fats, e.g. shortenings, cooking oils
# │   ├── coffee; tea; their substitutes; manufacture, preparation, or infusion thereof
# │   │   ├── tea; tea substitutes; preparations thereof
# │   │   ├── coffee; coffee substitutes; preparations thereof
# │   │   └── special features
# │   ├── cocoa; cocoa products, e.g. chocolate; substitutes for cocoa or cocoa products; confectionery; chewing gum; ice-cream; preparation thereof
# │   │   ├── cocoa; cocoa products, e.g. chocolate; substitutes therefor
# │   │   ├── sweetmeats; confectionery; marzipan; coated or filled products
# │   │   ├── chewing gum
# │   │   ├── other apparatus or process specially adapted for the chocolate or confectionery industry
# │   │   ├── frozen sweets, e.g. ice confectionery, ice-cream; mixtures therefor
# │   │   ├── containing organic compounds, e.g. synthetic flavouring agents
# │   │   ├── containing inorganic compounds or water in high or low amount
# │   │   └── products with special structure
# │   ├── protein compositions for foodstuffs; working-up proteins for foodstuffs; phosphatide compositions for foodstuffs
# │   │   ├── obtaining protein compositions for foodstuffs; bulk opening of eggs and separation of yolks from whites
# │   │   ├── working-up of proteins for foodstuffs
# │   │   └── phosphatide compositions for foodstuffs, e.g. lecithin
# │   ├── fodder
# │   │   ├── animal feeding-stuffs
# │   │   ├── accessory food factors for animal feeding-stuffs
# │   │   ├── processes specially adapted for preservation of materials in order to produce animal feeding-stuffs
# │   │   ├── shaping or working-up of animal feeding-stuffs
# │   │   └── feeding-stuffs specially adapted for particular animals
# │   ├── machines or apparatus for treating harvested fruit, vegetables or flower bulbs in bulk, not otherwise provided for; peeling vegetables or fruit in bulk; apparatus for preparing animal feeding- stuffs
# │   │   ├── machines or apparatus for extracting juice
# │   │   ├── machines for coring or stoning fruit, characterised by their feeding device
# │   │   ├── machines for stoning fruit or removing seed-containing sections from fruit, characterised by their stoning or removing device
# │   │   ├── machines for hulling, husking or cracking nuts
# │   │   ├── peeling vegetables or fruit
# │   │   ├── removing pith from stems
# │   │   ├── machines for cleaning, blanching, drying or roasting fruits or vegetables, e.g. coffee, cocoa, nuts
# │   │   ├── machines or apparatus for other treatment of fruits or vegetables for human purposes; machines or apparatus for topping or skinning flower bulbs
# │   │   └── apparatus specially adapted for preparing animal feeding-stuffs
# │   ├── shaping or working of foodstuffs, not fully covered by a single other subclass
# │   │   ├── shaping or working of foodstuffs characterised by the products
# │   │   ├── coating of foodstuffs; coatings therefor; making laminated, multi-layered, stuffed or hollow foodstuffs
# │   │   └── shaping or working of foodstuffs characterised by the process or apparatus
# │   ├── indexing scheme relating to foods, foodstuffs or non-alcoholic beverages
# │   │   ├── food compositions, function of food ingredients or processes for food or foodstuffs
# │   │   ├── function of food ingredients
# │   │   ├── food ingredients
# │   │   └── processes
# │   └── indexing scheme relating to lactic or propionic acid bacteria used in foodstuffs or food preparation
# │       ├── lactobacillus
# │       ├── streptococcus, lactococcus
# │       ├── leuconostoc
# │       ├── pediococcus
# │       ├── bifidobacterium
# │       └── propionibacterium
# ├── tobacco; cigars; cigarettes; simulated smoking devices; smokers' requisites
# │   ├── manufacture or preparation of tobacco for smoking or chewing; tobacco; snuff
# │   │   ├── preparation of tobacco on the plantation
# │   │   ├── preparing tobacco in the factory
# │   │   ├── stripping tobacco; treatment of stems or ribs
# │   │   ├── cutting tobacco
# │   │   ├── control of the moisture content of tobacco products, e.g. cigars, cigarettes, pipe tobacco
# │   │   ├── tobacco-twisting machines
# │   │   ├── tobacco for pipes, for cigars, e.g. cigar inserts, or for cigarettes; chewing tobacco; snuff
# │   │   └── chemical features or treatment of tobacco; tobacco substitutes, e.g. in liquid form
# │   ├── machines for making cigars or cigarettes
# │   │   ├── elements of cigar manufacture
# │   │   ├── complete manufacture of cigars; combinations of two or more elements of cigar manufacture
# │   │   └── making cigarettes; making tipping materials for, or attaching filters or mouthpieces to, cigars or cigarettes
# │   ├── cigars; cigarettes; tobacco smoke filters; mouthpieces for cigars or cigarettes; manufacture of tobacco smoke filters or mouthpieces
# │   │   ├── cigars; cigarettes
# │   │   └── tobacco smoke filters, e.g. filter-tips, filtering inserts; filters specially adapted for simulated smoking devices; mouthpieces for cigars or cigarettes
# │   └── smokers' requisites; match boxes; simulated smoking devices
# │       ├── tobacco pipes
# │       ├── tobacco pipes combined with other objects
# │       ├── bowls for pipes
# │       ├── mouthpieces for pipes; mouthpieces for cigar or cigarette holders
# │       ├── accessories for smokers' pipes
# │       ├── seasoning of tobacco pipes
# │       ├── appliances for smoking cigars or cigarettes
# │       ├── receptacles or boxes specially adapted for cigars, cigarettes, simulated smoking devices or cigarettes therefor
# │       ├── receptacles for cigarette papers
# │       ├── ash-trays
# │       ├── stands for smokers' requisites
# │       ├── cases for tobacco, snuff, or chewing tobacco
# │       ├── devices used by the smoker for controlling the moisture content of, or for scenting, cigars, cigarettes or tobacco
# │       ├── match receptacles or boxes
# │       ├── devices for igniting matches; holders for ignited matches
# │       ├── pipe-spills; devices for splitting matches
# │       ├── electrically operated smoking devices; component parts thereof; manufacture thereof; maintenance or testing thereof; charging means specially adapted therefor
# │       ├── simulated smoking devices other than electrically operated; component parts thereof; manufacture or testing thereof
# │       ├── smokers' requisites not otherwise provided for
# │       └── tobacco pipes; bad-covers or accessories for smokers' pipes
# ├── wearing apparel
# │   ├── shirts; underwear; baby linen; handkerchiefs
# │   │   ├── shirts
# │   │   ├── collars
# │   │   ├── fold-line formings for collars or cuffs
# │   │   ├── cuffs
# │   │   ├── undergarments
# │   │   ├── hosiery; panti-hose
# │   │   ├── baby linen
# │   │   ├── handkerchiefs
# │   │   └── selection of special materials for underwear
# │   ├── corsets; brassieres
# │   │   ├── corsets or girdles
# │   │   ├── brassieres
# │   │   └── machines, appliances, or methods for manufacturing corsets or brassieres
# │   ├── outerwear; protective garments; accessories
# │   │   ├── garments
# │   │   ├── overgarments
# │   │   ├── fur garments; garments of fur substitutes
# │   │   ├── bathing gowns; swim-suits, drawers, or trunks; beach suits
# │   │   ├── pyjamas; nightdresses
# │   │   ├── garments for children
# │   │   ├── professional, industrial or sporting protective garments, e.g. surgeons' gowns or garments protecting against blows or punches
# │   │   ├── convertible garments
# │   │   ├── gaiters; spats
# │   │   ├── gloves
# │   │   ├── wristbands or headbands, e.g. for absorbing sweat
# │   │   ├── scarves; head-scarves; neckerchiefs
# │   │   ├── neckties
# │   │   ├── details of garments or of their making
# │   │   ├── uniforms; parts or accessories of uniforms
# │   │   ├── materials specially adapted for outerwear
# │   │   ├── components of garments
# │   │   ├── details of garments
# │   │   ├── functions or special features of garments
# │   │   ├── materials for garments
# │   │   └── uses of garments specially adapted for specific purposes
# │   ├── garment fastenings; suspenders
# │   │   ├── fastening devices specially adapted for garments
# │   │   ├── braces
# │   │   ├── trouser supports attached to the shirt, waistcoat, or the like
# │   │   ├── devices for connecting underpants to trousers
# │   │   ├── belts, girdles, or waistbands for trousers or skirts
# │   │   ├── stocking or sock suspenders
# │   │   ├── other devices for supporting or holding stockings or socks during wear
# │   │   ├── shoulder or like straps
# │   │   ├── means for holding-down garments
# │   │   └── garment suspenders not otherwise provided for
# │   ├── artificial flowers; wigs; masks; feathers
# │   │   ├── artificial flowers, fruit, leaves, or trees; garlands
# │   │   ├── wigs
# │   │   ├── hair pieces, inserts, rolls, pads, or the like; toupées
# │   │   ├── masks or dominoes for concealing identity, e.g. for theatrical use
# │   │   ├── adornments of natural feathers; working natural feathers
# │   │   └── artificial feathers
# │   └── appliances or methods for making clothes, e.g. for dress-making, for tailoring, not otherwise provided for
# │       ├── measuring aids or methods
# │       ├── patterns for cutting-out; methods of drafting or marking-out such patterns, e.g. on the cloth
# │       ├── dress forms; bust forms; stands
# │       ├── devices or methods for trimming, levelling, or straightening the hems of garments
# │       ├── tracing-wheels
# │       ├── cloth-holders
# │       ├── cushions for needles or pins
# │       ├── boxes for needles or pins
# │       ├── supports for the body whilst trying-on or fitting
# │       ├── devices for applying chalk; sharpening or holding chalk
# │       ├── appliances or methods for marking-out, perforating, or making buttonholes
# │       ├── mending garments by adhesives or adhesive patches
# │       ├── other aids for tailors
# │       ├── machines or appliances for folding the edges of collars, cuffs, or the like while manufacturing
# │       ├── machines, appliances or methods for setting fastener-elements on garments
# │       ├── machines or appliances for making garments from natural or artificial fur
# │       ├── multi-step production lines for making clothes
# │       └── other methods, machines or appliances
# ├── headwear
# │   ├── hats; head coverings
# │   │   ├── hats; caps; hoods
# │   │   ├── helmets; helmet covers ; other protective head coverings
# │   │   ├── veils; holders for veils
# │   │   └── fastening means for head coverings; elastic cords; ladies' hat fasteners
# │   └── manufacturing or trimming head coverings, e.g. hats
# │       ├── manufacturing hats
# │       ├── manufacturing helmets by processes not otherwise provided for
# │       ├── miscellaneous appliances for hat-making, e.g. for making wire forms for hat-frames; apparatus for changing the form or size of finished hats
# │       └── fittings or trimmings for hats, e.g. hat-bands
# ├── footwear
# │   ├── characteristic features of footwear; parts of footwear
# │   │   ├── footwear characterised by the material
# │   │   ├── footwear characterised by the shape or the use
# │   │   ├── footwear for sporting purposes
# │   │   ├── footwear with health or hygienic arrangements
# │   │   ├── footwear characterised by the assembling of the individual parts
# │   │   ├── footwear with arrangements to facilitate putting-on or removing, e.g. with straps
# │   │   ├── soles; sole-and-heel integral units
# │   │   ├── welts for footwear
# │   │   ├── insoles for insertion, e.g. footbeds or inlays, for attachment to the shoe after the upper has been joined
# │   │   ├── shoe-shaped inserts; inserts covering the instep
# │   │   ├── heels; top-pieces or top-lifts
# │   │   └── uppers; boot legs; stiffeners; other single parts of footwear
# │   ├── fastenings or attachments of footwear; laces in general
# │   │   ├── shoe lacing fastenings
# │   │   ├── hooks for laces; guards for hooks
# │   │   ├── eyelets
# │   │   ├── holding-devices for laces
# │   │   ├── laces; laces in general for garments made of textiles, leather, or plastics
# │   │   ├── other fastenings specially adapted for shoes
# │   │   ├── wear-resisting attachments
# │   │   ├── non-skid devices or attachments
# │   │   └── spurs
# │   └── machines, tools, equipment or methods for manufacturing or repairing footwear
# │       ├── foot or last measuring devices; measuring devices for shoe parts
# │       ├── lasts
# │       ├── machines for cutting, ornamenting, marking or otherwise working up shoe part blanks
# │       ├── devices for binding the uppers upon the lasts
# │       ├── machines for preliminary treatment or assembling of upper-parts, counters, or insoles on their lasts preparatory to the pulling-over or lasting operations; applying or removing protective coverings
# │       ├── machines for pulling-over the uppers when loosely laid upon the last and tacking the toe end
# │       ├── pulling-over or lasting machines for binding the toe end with cord, string, or wire; machines for lasting with clamps; lasting machines with sewing devices, also for platform shoes
# │       ├── pulling-over or lasting machines with oscillating shoe supports
# │       ├── hand lasting; lasting pincers
# │       ├── lasting machines
# │       ├── single parts for pulling-over or lasting machines
# │       ├── devices for gluing shoe parts
# │       ├── machines for trimming as an intermediate operation
# │       ├── machines for making soles from strips of material
# │       ├── machines for making or inserting shank stiffeners
# │       ├── machines for assembling lifts for heels
# │       ├── presses for shaping pre-existing loose soles, shoe bottoms or soles fixed to shoe bottoms
# │       ├── machines for roughening soles or other shoe parts preparatory to gluing
# │       ├── machines for making foot-supporting pads or instep-raisers for flat feet
# │       ├── machines for making stitch lips, or other preparatory treatment of soles or insoles before fixing same
# │       ├── machines for attaching welts or rands
# │       ├── machines for trimming or butting welts fixed on uppers
# │       ├── machines for pounding
# │       ├── machines for lip-setting
# │       ├── machines for trimming-off surplus material along the inseam
# │       ├── machines for flattening, pressing, or rubbing the inseams of lasted shoes
# │       ├── machines for attaching the welt ends
# │       ├── machines for rasping the lasting-margins of shoes which are sewn through
# │       ├── machines for nail-pulling, nail-cutting, or nail-detecting
# │       ├── machines for carrying-out other finishing operations
# │       ├── machines for fastening soles or heels by means of screws or screwed wire
# │       ├── shoe-nailing machines
# │       ├── elements of nailing machines; nail-feeding devices
# │       ├── nailing devices on pulling-over or lasting machines
# │       ├── combined heel-pressing and nailing machines
# │       ├── machines for attaching top-lifts
# │       ├── heel-presses without nailing apparatus; machines for pressing single lifts or punching holes for nailing
# │       ├── machines or apparatus for turning, e.g. for making turn-shoes
# │       ├── edge or heel cutters; machines for trimming the heel breast
# │       ├── sole-levelling machines with rolls
# │       ├── stitch-separating or seam-indenting machines
# │       ├── edge-indenting machines
# │       ├── shoe-finishing machines
# │       ├── machines for making pulling-on pieces
# │       ├── machines for making laces
# │       ├── setting or removing eyelets, buttons, lacing-hooks, or elastic gussets in shoes
# │       ├── shoe machines with conveyors for jacked shoes or for shoes or shoe parts
# │       ├── machines for making shoes with out-turned flanges of the uppers or for making moccasins
# │       ├── machines for skiving or removing heel-lifts, heels, or soles, or for removing stitches, preparatory to repair
# │       ├── racks for receiving or transporting shoes or shoe parts; other conveying means
# │       ├── driving or controlling mechanisms of shoe machines; frames for shoe machines
# │       └── machines or methods characterised by special features
# ├── haberdashery; jewellery
# │   ├── buttons, pins, buckles, slide fasteners, or the like
# │   │   ├── buttons
# │   │   ├── collar-studs
# │   │   ├── sleeve-links
# │   │   ├── retainers or tethers for neckties, cravats, neckerchiefs, or the like, e.g. tie-clips, spring clips with attached tie-tethers, woggles, pins with associated sheathing members tetherable to clothing
# │   │   ├── cards for buttons, collar-studs, or sleeve-links
# │   │   ├── hat, scarf, or safety pins or the like
# │   │   ├── buckles; similar fasteners for interconnecting straps or the like, e.g. for safety belts
# │   │   ├── hook or eye fasteners
# │   │   ├── key-rings
# │   │   ├── press-button or snap fasteners
# │   │   ├── fasteners of the touch-and-close type; making such fasteners
# │   │   └── slide fasteners
# │   ├── personal adornments, e.g. jewellery; coins
# │   │   ├── brooches or clips in their decorative or ornamental aspect
# │   │   ├── medals; badges
# │   │   ├── bracelets; wrist-watch straps; fastenings for bracelets or wrist-watch straps
# │   │   ├── ear-rings; devices for piercing the ear-lobes
# │   │   ├── finger-rings
# │   │   ├── watch chains; ornamental chains
# │   │   ├── connectible jewellery
# │   │   ├── other forms of jewellery
# │   │   ├── gems or the like
# │   │   ├── devices for preventing pilfering of watches or jewellery
# │   │   ├── coins; emergency money; beer or gambling coins or tokens, or the like
# │   │   ├── rosaries
# │   │   ├── miscellaneous fancy ware for personal wear, e.g. pendants, crosses, crucifixes, charms
# │   │   └── making jewellery or other personal adornments
# │   └── indexing scheme relating to buttons, pins, buckles or slide fasteners, and to jewellery, bracelets or other personal adornments
# │       ├── general types of fasteners
# │       ├── fastening by snap action
# │       ├── fastening by use of magnets
# │       ├── fastening by use of touch and close elements
# │       └── accessories for fastening means
# ├── hand or travelling articles
# │   ├── walking sticks
# │   │   ├── sticks with supporting, hanging or carrying means
# │   │   ├── sticks combined with other objects
# │   │   ├── walking sticks or umbrellas convertible into seats; hunting sticks
# │   │   ├── other sticks, e.g. of cranked shape
# │   │   ├── details
# │   │   ├── umbrellas characterised by their shape or attachment
# │   │   ├── umbrellas made of paper
# │   │   ├── umbrellas with detachable covers
# │   │   ├── tiltable umbrellas
# │   │   ├── special folding or telescoping of umbrellas
# │   │   ├── umbrellas convertible into walking sticks
# │   │   ├── other umbrellas
# │   │   ├── details of umbrellas
# │   │   └── ladies' or like fans
# │   ├── purses; luggage; hand carried bags
# │   │   ├── purses; money-bags; wallets
# │   │   ├── flexible luggage; handbags
# │   │   ├── rigid or semi-rigid luggage
# │   │   ├── collapsible or extensible purses, luggage, bags or the like
# │   │   ├── purses, luggage or bags convertible into objects for other use
# │   │   └── details; accessories
# │   ├── hairdressing or shaving equipment; equipment for cosmetics or cosmetic treatments, e.g. for manicuring or pedicuring
# │   │   ├── curling-tongs
# │   │   ├── hair-curling or hair-waving appliances; appliances for hair dressing treatment not otherwise provided for
# │   │   ├── separate devices designed for heating hair curlers or hair-wavers
# │   │   ├── details of, or accessories for, hair-curling or hair-waving devices
# │   │   ├── processes of waving, straightening or curling hair
# │   │   ├── hair-holding devices; accessories therefor
# │   │   ├── devices for washing the hair or the scalp; similar devices for colouring the hair
# │   │   ├── hair drying devices; accessories therefor
# │   │   ├── hair combs for care of the hair; accessories therefor
# │   │   ├── hair-singeing apparatus; apparatus for removing superfluous hair, e.g. tweezers
# │   │   ├── shaving accessories
# │   │   ├── manicuring or pedicuring implements
# │   │   ├── artificial nails
# │   │   ├── containers or accessories specially adapted for handling toilet or cosmetic powder
# │   │   ├── containers or accessories specially adapted for handling liquid toilet or cosmetic substances, e.g. perfumes
# │   │   ├── sachet pads for liquid substances
# │   │   ├── casings or accessories for storing or handling solid or pasty toilet or cosmetic substances, e.g. shaving soap, lipstick, make-up
# │   │   ├── hand, pocket, or shaving mirrors
# │   │   └── other cosmetic or personal care articles, e.g. for hairdressers' rooms
# │   └── travelling or camp equipment: sacks or packs carried on the body
# │       ├── travelling or camp articles
# │       ├── travelling or camp articles which may be converted into other articles or into objects for other use; sacks or packs carried on the body and convertible into other articles or into objects for other use
# │       └── holders or carriers for hand articles; holders or carriers for use while travelling or camping
# ├── brushware
# │   ├── brushes
# │   │   ├── brush bodies and bristles moulded as a unit
# │   │   ├── brushes characterised by the way in which the bristles are fixed or joined in or on the brush body or carrier
# │   │   ├── brush bodies; handles integral with brushware
# │   │   ├── bristle carriers arranged in the brush body
# │   │   ├── arrangements of the bristles in the brush body
# │   │   ├── brushes with reservoir or other means for applying substances, e.g. paints, pastes, water
# │   │   ├── brushes with driven brush bodies or carriers
# │   │   ├── other brushes; brushes with additional arrangements
# │   │   ├── accessories for brushes
# │   │   └── brushes characterized by their functions, uses or applications
# │   └── manufacture of brushes
# │       ├── bristles; selection of materials for bristles
# │       ├── preparing
# │       ├── devices for preparing quills for use as carriers for bristles
# │       ├── pressing devices for making brooms composed of brushwood or the like
# │       └── machines for finishing brushes
# ├── furniture; domestic articles or appliances; coffee mills; spice mills; suction cleaners in general
# │   ├── tables; desks; office furniture; cabinets; drawers; general details of furniture
# │   │   ├── extensible tables
# │   │   ├── folding or stowable tables
# │   │   ├── suspended or hinged panels forming a table; wall tables
# │   │   ├── tables of rigid construction
# │   │   ├── tables with tops of variable height
# │   │   ├── tables with tops revolvable on vertical spindles
# │   │   ├── details of tables or desks
# │   │   ├── writing-tables
# │   │   ├── reading-desks; lecterns; pulpits
# │   │   ├── tables or desks for office equipment, e.g. typewriters, keyboards
# │   │   ├── bed-tables; trays; reading-racks; book-rests
# │   │   ├── card tables; tables for other games
# │   │   ├── drawing desks or tables; carriers for drawing-boards
# │   │   ├── sewing-tables
# │   │   ├── service or tea tables, trolleys, or wagons
# │   │   ├── kitchen or dish-washing tables
# │   │   ├── tables combined with ironing-boards, washers, wringers, or the like
# │   │   ├── tables adapted for other particular purposes
# │   │   ├── school forms; benches or forms combined with desks
# │   │   ├── school desks or tables
# │   │   ├── cabinets, racks or shelf units, characterised by features enabling folding of the cabinet or the like
# │   │   ├── cabinets, racks or shelf units, characterised by features enabling enlarging in height, length, or depth
# ...
# │   │   ├── devices for introducing or retaining media, e.g. remedies, in cavities of the body
# │   │   ├── devices for applying , e.g. spreading, media, e.g. remedies, on the human body
# │   │   ├── other apparatus for introducing media into the body
# │   │   ├── tubes, tube connectors, tube couplings, valves, access sites or the like, specially adapted for medical use
# │   │   ├── blood pumps; devices for mechanical circulatory actuation; balloon pumps for circulatory assistance
# │   │   ├── special media to be introduced, removed or treated
# │   │   ├── general characteristics of the apparatus
# │   │   ├── characteristics of a physical parameter; associated device therefor
# │   │   ├── methods of manufacture, assembly or production
# │   │   ├── ancillary equipment
# │   │   ├── anatomical parts of the body
# │   │   ├── measuring parameters of the user
# │   │   ├── specially adapted for neonatal use
# │   │   └── specially adapted for animals
# │   ├── electrotherapy; magnetotherapy; radiation therapy; ultrasound therapy
# │   │   ├── electrotherapy; circuits therefor
# │   │   ├── magnetotherapy
# │   │   ├── radiation therapy
# │   │   └── ultrasound therapy
# │   ├── specific therapeutic activity of chemical compounds or medicinal preparations
# │   │   ├── drugs for disorders of the alimentary tract or the digestive system
# │   │   ├── drugs for disorders of the metabolism
# │   │   ├── drugs for disorders of the endocrine system
# │   │   ├── drugs for disorders of the blood or the extracellular fluid
# │   │   ├── drugs for disorders of the cardiovascular system
# │   │   ├── drugs for disorders of the respiratory system
# │   │   ├── drugs for disorders of the urinary system
# │   │   ├── drugs for genital or sexual disorders; contraceptives
# │   │   ├── drugs for dermatological disorders
# │   │   ├── drugs for skeletal disorders
# │   │   ├── drugs for disorders of the muscular or neuromuscular system
# │   │   ├── anaesthetics
# │   │   ├── drugs for disorders of the nervous system
# │   │   ├── drugs for disorders of the senses
# │   │   ├── non-central analgesic, antipyretic or anti-inflammatory agents, e.g antirheumatic agents; non-steroidal anti-inflammatory drugs
# │   │   ├── antiinfectives
# │   │   ├── antiparasitic agents
# │   │   ├── antineoplastic agents
# │   │   ├── drugs for immunological or allergic disorders
# │   │   ├── general protective or antinoxious agents
# │   │   └── drugs used in surgical methods, e.g. surgery adjuvants for preventing adhesion or for vitreum substitution
# │   └── specific use of cosmetics or similar toilet preparations
# │       ├── make-up preparations; body powders; preparations for removing make-up
# │       ├── manicure or pedicure preparations
# │       ├── preparations for care of the hair
# │       ├── preparations for affecting hair growth
# │       ├── preparations for removing hair or for aiding hair removal
# │       ├── preparations for care of the teeth, of the oral cavity or of dentures; dentifrices, e.g. toothpastes; mouth rinses
# │       ├── formulations or additives for perfume preparations
# │       ├── anti-perspirants or body deodorants
# │       ├── barrier preparations; preparations brought into direct contact with the skin for affording protection against external influences, e.g. sunlight, x-rays or other harmful rays, corrosive materials, bacteria or insect stings
# │       └── preparations for care of the skin
# ├── life-saving; fire-fighting
# │   ├── devices, apparatus or methods for life-saving
# │   │   ├── devices for lowering persons from buildings or the like
# │   │   ├── devices or single parts for facilitating escape from buildings or the like, e.g. protection shields, protection screens; portable devices for preventing smoke penetrating into distinct parts of buildings
# │   │   ├── other devices for rescuing from fire
# │   │   ├── respiratory apparatus
# │   │   ├── component parts for respiratory or breathing apparatus
# │   │   ├── devices for reconditioning breathing air in sealed rooms
# │   │   ├── special devices for ventilating gasproof shelters
# │   │   ├── installations affording protection against poisonous or injurious substances, e.g. with separate breathing apparatus
# │   │   ├── protective clothing affording protection against heat or harmful chemical agents or for use at high altitudes
# │   │   ├── breathing masks or helmets, e.g. affording protection against chemical agents or for use at high altitudes or incorporating a pump or compressor for reducing the inhalation effort
# │   │   ├── cartridges with absorbing substances for respiratory apparatus
# │   │   ├── devices for producing oxygen from chemical substances for respiratory apparatus
# │   │   ├── filters for breathing-protection purposes
# │   │   ├── devices for storing or holding or carrying respiratory or breathing apparatus
# │   │   ├── methods or devices for testing respiratory or breathing apparatus for high altitudes
# │   │   ├── devices, e.g. installations, for rendering harmless or for keeping off harmful chemical agents
# │   │   ├── containers or portable cabins for affording breathing protection with devices for reconditioning the breathing air or for ventilating, in particular those that are suitable for invalids or small children
# │   │   ├── devices for allowing seemingly-dead persons to escape or draw attention; breathing apparatus for accidentally buried persons
# │   │   └── safety belts or body harnesses; similar equipment for limiting displacement of the human body, especially in case of sudden changes of motion
# │   ├── fire-fighting
# │   │   ├── fire prevention or containment
# │   │   ├── fire prevention, containment or extinguishing specially adapted for particular objects or places
# │   │   ├── flame traps allowing passage of gas but not of flame or explosion wave
# │   │   ├── making of fire-extinguishing materials immediately before use
# │   │   ├── hand tools or accessories specially adapted for fire-fighting, e.g. tool boxes
# │   │   ├── portable extinguishers with manually-operated pumps
# │   │   ├── portable extinguishers which are permanently pressurised or pressurised immediately before use
# │   │   ├── extinguishers essentially of the knapsack type
# │   │   ├── hand fire-extinguishers essentially in the form of pistols or rifles
# │   │   ├── hand fire-extinguishers in which the extinguishing substance is expelled by an explosion; exploding containers thrown into the fire
# │   │   ├── portable extinguishers with power-driven pumps
# │   │   ├── fire-fighting land vehicles
# │   │   ├── fire-fighting vessels or like floating structures
# │   │   ├── delivery of fire-extinguishing material
# │   │   ├── hose accessories
# │   │   ├── permanently-installed equipment
# │   │   └── control of fire-fighting equipment
# │   └── chemical means for extinguishing fires or for combating or protecting against harmful chemical agents; chemical materials for use in breathing apparatus
# │       ├── fire-extinguishing compositions; use of chemical substances in extinguishing fires
# │       ├── processes for making harmful chemical substances harmless or less harmful, by effecting a chemical change in the substances
# │       ├── composition of materials for coverings or clothing affording protection against harmful chemical agents
# │       ├── composition of materials for transparent parts of gas-masks, respirators, breathing bags, or helmets
# │       ├── composition of chemical substances for use in breathing apparatus
# │       ├── harmful chemical substances made harmless, or less harmful, by effecting chemical change
# │       └── aspects of processes for making harmful chemical substances harmless, or less harmful, by effecting chemical change in the substances
# └── sports; games; amusements
#     ├── apparatus for physical training, gymnastics, swimming, climbing, or fencing; ball games; training equipment
#     │   ├── horizontal bars
#     │   ├── parallel bars or similar apparatus
#     │   ├── balance beams
#     │   ├── apparatus for jumping
#     │   ├── mats or the like for absorbing shocks for jumping, gymnastics or the like
#     │   ├── freely-suspended gymnastic apparatus
#     │   ├── climbing poles, frames, or stages
#     │   ├── clubs for gymnastics or the like , e.g. for swinging exercises
#     │   ├── exercising apparatus combining several parts such as ladders, rods, beams, slides
#     │   ├── hoop exercising apparatus
#     │   ├── exercising apparatus for developing or strengthening the muscles or joints of the body by working against a counterforce, with or without measuring devices
#     │   ├── exercising apparatus specially adapted for conditioning the cardio-vascular system, for training agility or co-ordination of movements
#     │   ├── exercising apparatus specially adapted for particular parts of the body
#     │   ├── electric or electronic controls for exercising apparatus of preceding groups; controlling or monitoring of exercises, sportive games, training or athletic performances
#     │   ├── stilts or the like
#     │   ├── apparatus for climbing poles, trees, or the like
#     │   ├── apparatus for mountaineering
#     │   ├── swimming aids
#     │   ├── swimming equipment attachable to the head, e.g. swim caps or goggles
#     │   ├── swimming framework with driving mechanisms operated by the swimmer or by a motor
#     │   ├── solid balls; rigid hollow balls;  marbles
#     │   ├── hollow non-inflatable balls
#     │   ├── hollow inflatable balls
#     │   ├── balls with special arrangements
#     │   ├── apparatus or methods for manufacturing balls
#     │   ├── devices for handling or treating balls , e.g. for holding or carrying balls
#     │   ├── stringed rackets, e.g. for tennis
#     │   ├── stringing tennis, badminton or like rackets; strings therefor; maintenance of racket strings
#     │   ├── golf clubs
#     │   ├── bags for golf clubs; stands for golf clubs for use on the course; wheeled carriers specially adapted for golf bags
#     │   ├── golfing accessories
#     │   ├── details or accessories of golf clubs, bats, rackets or the like
#     │   ├── tennis nets or accessories for tennis or like games , e.g. volley-ball
#     │   ├── targets or goals for ball games
#     │   ├── implements for throwing ; mechanical projectors, e.g. using spring force
#     │   ├── training appliances or apparatus for special sports
#     │   ├── application of clubs, bats, rackets or the like to the sporting activity ; particular sports involving the use of balls and clubs, bats, rackets, or the like
#     │   ├── characteristics or parameters related to the user or player
#     │   ├── characteristics of used materials
#     │   ├── space saving
#     │   ├── exercising combined with therapy
#     │   ├── training methods
#     │   ├── measuring of physical parameters relating to sporting activity
#     │   ├── miscellaneous features of sport apparatus, devices or equipment
#     │   ├── measuring physiological parameters of the user
#     │   └── sports without balls
#     ├── skates; skis; roller skates; design or layout of courts, rinks or the like
#     │   ├── skates
#     │   ├── accessories for skates
#     │   ├── skis or snowboards
#     │   ├── devices preventing skis from slipping back; ski-stoppers or ski-brakes
#     │   ├── ski bindings
#     │   ├── snowboard bindings
#     │   ├── accessories for skiing or snowboarding
#     │   ├── snow shoes
#     │   ├── roller skates; skate-boards
#     │   ├── design or layout of playing courts, rinks, bowling greens or areas for water-skiing; covers therefor
#     │   ├── use of skates, skis, roller-skates, snowboards and courts
#     │   └── special features of skates, skis, roller-skates, snowboards and courts
#     ├── bowling games, e.g. skittles, bocce or bowls; installations therefor; bagatelle or similar games; billiards
#     │   ├── installations for bowling games, e.g. bowling-alleys or bocce courts
#     │   ├── table bowling games; miniature bowling-alleys; bowling games
#     │   ├── accessories for bowling-alleys or table alleys
#     │   ├── games of pins, e.g. ninepins, with tethered balls
#     │   ├── pins
#     │   ├── bagatelles or similar games
#     │   └── billiards, e.g. carom billiards or pocket billiards; billiard tables
#     ├── card, board, or roulette games; indoor games using small moving playing bodies; video games; games not otherwise provided for
#     │   ├── card games
#     │   ├── board games; raffle games
#     │   ├── roulette games
#     │   ├── indoor games using small moving playing bodies, e.g. balls, discs or blocks
#     │   ├── games not otherwise provided for
#     │   ├── game accessories of general use , e.g. score counters, boxes
#     │   ├── video games
#     │   ├── miscellaneous game characteristics
#     │   └── features of games using an electronically generated display having two or more dimensions, e.g. on a television screen, showing representations related to the game
#     ├── merry-go-rounds; swings; rocking-horses; chutes; switchbacks; similar devices for public amusement
#     │   ├── roundabouts
#     │   ├── water roundabouts, e.g. freely floating
#     │   ├── games on roundabouts
#     │   ├── up-and-down hill tracks; switchbacks
#     │   ├── swings
#     │   ├── see-saws
#     │   ├── cradle swings; rocking-horses; like devices resting on the ground
#     │   ├── rocking horses on runners adapted for progressive movement
#     │   ├── hobby-horses
#     │   ├── toy animals for riding
#     │   ├── chutes; helter-skelters
#     │   ├── rotating or rocking pots , e.g. by moving the whole body
#     │   ├── autocar-like self-drivers; runways therefor
#     │   ├── russian swings; great wheels, e.g. ferris wheels
#     │   ├── rolling drums turning somersaults with or without rolling seats
#     │   ├── amusement arrangements
#     │   ├── devices allowing competitions between several persons, not otherwise provided for
#     │   └── means for transporting or storing public amusement arrangements
#     ├── toys, e.g. tops, dolls, hoops or building blocks
#     │   ├── tops
#     │   ├── dolls
#     │   ├── musical or noise- producing devices for additional toy effects other than acoustical
#     │   ├── toy figures led or propelled by the user
#     │   ├── special methods or compositions for the manufacture of dolls, toy animals, toy figures, or parts thereof
#     │   ├── self-movable toy figures
#     │   ├── toy figures with self-moving parts, with or without movement of the toy as a whole
#     │   ├── other gravity-operated toy figures
#     │   ├── toy vehicles, e.g. with self-drive;
#     │   ├── highways or trackways for toys; propulsion by special interaction between vehicle and track
#     │   ├── model railways
#     │   ├── other toy railways
#     │   ├── toy boats; floating toys; other aquatic toy devices
#     │   ├── toy aircraft; other flying toys; starting or launching devices therefor
#     │   ├── drive mechanisms for toys in general
#     │   ├── remote-control arrangements specially adapted for toys, e.g. for toy vehicles
#     │   ├── gearing for toys
#     │   ├── other toys
#     │   ├── jokes; confetti, streamers, or other dance favours ; cracker bonbons or the like
#     │   └── computerized interactive toys, e.g. dolls
#     ├── devices for theatres, circuses, or the like; conjuring appliances or the like
#     │   ├── stage arrangements
#     │   ├── equipment for, or arrangement of, circuses or arenas
#     │   ├── auxiliaries for producing special effects on stages, or in circuses or arenas
#     │   ├── auxiliary apparatus for artistes
#     │   ├── centrifugal tracks, loop-the-loops or the like
#     │   ├── labyrinths
#     │   ├── panoramas, dioramas, stereoramas, or the like
#     │   ├── peep-shows, e.g. raree-shows; kaleidoscopic or other opalescence exhibitions
#     │   ├── apparatus for performing colour-music
#     │   ├── puppet, marionette, or shadow shows or theatres
#     │   ├── conjuring appliances; auxiliary apparatus for conjurers
#     │   └── equipment specially adapted for cinemas
#     └── racing; riding sports; equipment or accessories therefor
#         ├── race-courses; race-tracks
#         └── equipment or accessories for racing or riding sports

# %% [markdown]
# ## Parsing rules

# %% [markdown]
# ### 1. split titles by semicolon [x]
#
# NOTE: here, we prefer not to split the content by "OR", because all the parts connected by OR eventually form an overall concept or a plausible event.

# %%
# PHYSICS
# ├── MEASURING; TESTING
# │   ├── MEASURING LENGTH, THICKNESS OR SIMILAR LINEAR DIMENSIONS; MEASURING ANGLES; MEASURING AREAS; MEASURING IRREGULARITIES OF SURFACES OR CONTOURS

# %% [markdown]
# TODO 如果不用or分裂，检索问题？
# fasttext

# %% [markdown]
# ### 2. split titles with examples (with e.g.) [x]

# %%
# ├── PHOTOGRAPHY; CINEMATOGRAPHY; ANALOGOUS TECHNIQUES USING WAVES OTHER THAN OPTICAL WAVES; ELECTROGRAPHY; HOLOGRAPHY
# │   ├── APPARATUS OR ARRANGEMENTS FOR TAKING PHOTOGRAPHS OR FOR PROJECTING OR VIEWING THEM; APPARATUS OR ARRANGEMENTS EMPLOYING ANALOGOUS TECHNIQUES USING WAVES OTHER THAN OPTICAL WAVES; ACCESSORIES THEREFOR
# │   ├── PHOTOMECHANICAL PRODUCTION OF TEXTURED OR PATTERNED SURFACES, e.g. FOR PRINTING, FOR PROCESSING OF SEMICONDUCTOR DEVICES; MATERIALS THEREFOR; ORIGINALS THEREFOR; APPARATUS SPECIALLY ADAPTED THEREFOR;

# ├── MUSICAL INSTRUMENTS; ACOUSTICS
# │   ├── REPRESENTATION OF MUSIC; RECORDING MUSIC IN NOTATION FORM; ACCESSORIES FOR MUSIC OR MUSICAL INSTRUMENTS, e.g. SUPPORTS

# %%
# ├── MEASURING; TESTING
# │   ├── SCANNING-PROBE TECHNIQUES OR APPARATUS; APPLICATIONS OF SCANNING-PROBE TECHNIQUES, e.g. SCANNING PROBE MICROSCOPY [SPM]

# 缩写是否需要新建一列变量？

# %% [markdown]
# e.g. + examples starts with preposition (for) ==> add the e.g. content after the main title as hyponym nodes / v.ed
#
#     NOTE: e.g. is dedicated to the closest one as a supplement (with; split).

# %% [markdown]
# Construction or design features not otherwise provided for; manufacturing or production;
#
# remove titles with "not provided for" inside

# %%
# │   │   │   │   └── Component parts, details, e.g. sealings, lubrication
# │   │   │   │       ├── Cylinders
# │   │   │   │       ├── Actuating or actuated elements
# │   │   │   │       │   └── Actuating or actuated element bearing means or driving or driven axis bearing means

# %% [markdown]
# "sealings, lubrication" will be at the same level of Cylinders

# %% [markdown]
# ### 3. with "such" in title [x]

# %%
# │       ├── patterns for cutting-out; methods of drafting or marking-out such patterns

# %%
# ├── CONTROLLING; REGULATING
# │   ├── CONTROL OR REGULATING SYSTEMS IN GENERAL; FUNCTIONAL ELEMENTS OF SUCH SYSTEMS; MONITORING OR TESTING ARRANGEMENTS FOR SUCH SYSTEMS OR ELEMENTS

# %% [markdown]
# remove "in general" at the end of title

# %%
    # │   ├── exercising apparatus combining several parts such as ladders, rods, beams, slides

# %% [markdown]
# keep titles with "such as" "such a", also with those the noun has already appeared before

# %%
# │   │   │   ├── filters formed by clamping together several filtering elements or parts of such elements

# %% [markdown]
# ### 4. children nodes should not contain in parent node [x]

# %%
# ├── EDUCATION; CRYPTOGRAPHY; DISPLAY; ADVERTISING; SEALS
# │   ├── DISPLAYING; ADVERTISING; SIGNS; LABELS OR NAME-PLATES; SEALS

# %% [markdown]
# repetited words in title-hypernym
#
# SEALS in the previous example

# %% [markdown]
# ### 5. if title starts with preposition ==> connect with parent node [x]

# %%
# │   │   │   │   └── Controlling
# │   │   │   │       ├── by using a valve in a system with several pump or motor chambers, wherein the flow path through the chambers can be changed, e.g. series-parallel
# │   │   │   │       ├── by changing the effective cross sectional piston working surface
# │   │   │   │       ├── by changing the effective piston stroke
# │   │   │   │       │   └── by changing the excentricity of one element relative to another element

# %% [markdown]
# TODO:
#
# 1. schema de database
#
# 2. merge with wikipedia
